# %%
import pandas as pd
a=pd.read_csv("rahul.csv")
a.head()
a["Variable_code"]
a["rahul"]="rahul rathore best"
a["rahul"]
a.insert(1,column="rahul1",value="r")
a.head(10)
# Out:
#    Year rahul1 Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0  2017      r                     Level 1                99999
# 1  2017      r                     Level 1                99999
# 2  2017      r                     Level 1                99999
# 3  2017      r                     Level 1                99999
# 4  2017      r                     Level 1                99999
# 5  2017      r                     Level 1                99999
# 6  2017      r                     Level 1                99999
# 7  2017      r                     Level 1                99999
# 8  2017      r                     Level 1                99999
# 9  2017      r                     Level 1                99999
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0     All industries    Dollars (millions)           H01
# 1     All industries    Dollars (millions)           H04
# 2     All industries    Dollars (millions)           H05
# ...
